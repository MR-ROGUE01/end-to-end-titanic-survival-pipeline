# %%
import pickle
import numpy as np
import pandas as pd

# %%
pipe = pickle.load(open('titanic_pipe.pkl','rb'))

# %%
test_input = np.array([3,'male',35.0,0,0,8.0500,'S'],dtype=object).reshape(1,7)

# %%
test_input2 = pd.DataFrame({
    'Pclass':[1],
    'Sex':['male'],
    'Age':[18.0],
    'SibSp':[0],
    'Parch':[0],
    'Fare':[8.0500],
    'Embarked':['S']
})

# %%
pipe.predict(test_input)
# Out:
# C:\Users\ACER\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\ACER\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])

# %%
pipe.predict(test_input2)
# Out:
# array([0])
